# %% [markdown]
# ## Starting Off
#
# Message me one question you have about APIs. Any question at all

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
from  keys  import  client_id, api_key

# %%
print(api_key)
# Out:
# m3thcmik5l2yJb4BAfg-uYJyI82T6W52bEBS_HFE4nzUudzabtUagvEnJUdwb9wfSDjTZD1C2-qdcpLU6x-suSaz8ijI2b4hc3Brygw8hmNGm_skfaMen_JZ6EvzX3Yx

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'restaurant' 

#where do you want to perform this search
location = 'manhattan'

# what is your other parameter you want to search against
categories = 'bars'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50 
                
            }

# %%
offset 0 
while offset <1000:  
    api
    offset +=50

# %%
url_params
# Out:
# {'term': 'restaurant',
#  'location': 'manhattan',
#  'categories': 'bars',
#  'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
response.text
# Out:
# '{"businesses": [{"id": "ETgJqJHV7BW6pIr9Ox74sA", "alias": "am\\u00e9lie-new-york", "name": "Am\\u00e9lie", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA", "review_count": 2702, "categories": [{"alias": "french", "title": "French"}, {"alias": "wine_bars", "title": "Wine Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327, "longitude": -73.99766}, "transactions": ["pickup", "restaurant_reservation", "delivery"], "price": "$$", "location": {"address1": "22 W 8th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10011", "country": "US", "state": "NY", "display_address": ["22 W 8th St", "New York, NY 10011"]}, "phone": "+12125332962", "display_phone": "(212) 533-2962", "distance": 3464.4669936751793}, {"id": "6Ct7OeTRn4caY9g0swFBsw", "alias": "la-contenta-new-york", "name": "La Contenta", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/FwZAyPgdKdPGQ8aAGKh3-w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/la-contenta-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA", "review_count": 763, "categories": [{"alias": "mexican", "title": "Mexican"}, {"alias": "bars", "title": "Bars"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.5, "coordinates": {"latitude": 40.71873, "longitude": -73.98691}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "102 Norfolk St", "address2": "", "address3": "", "city": "New York", "zip_code": "10002", "country": "US", "state": "NY", "display_address": ["102 Norfolk St", "New York, NY 10002"]}, "phone": "+12124324180", "display_phone": "(212) 432-4180", "distance": 4662.3743595723645}, {"id": "ooYUO3Pq_qypc1NXFzeLYQ", "alias": "city-vineyard-new-york", "name": "City Vineyard", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/EQkP8Wd2bC_411mQMBtwXg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/city-vineyard-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA", "review_count": 940, "categories": [{"alias": "wine_bars", "title": "Wine Bars"}, {"alias": "newamerican", "title": "American (New)"}, {"alias": "venues", "title": "Venues & Event Spaces"}], "rating": 4.0, "coordinates": {"latitude": 40.7205582, "longitude": -74.0118093}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "233 West St", "address2": "", "address3": null, "city": "New York", "zip_code": "10013", "country": "US", "state": "NY", "display_address": ["233 West St", "New York, NY 10013"]}, "phone": "+16466778350", "display_phone": "(646) 677-8350", "distance": 5193.210804405722}, {"id": "ssGhu4n3emZ9kEPVf371IQ", "alias": "cookshop-new-york", "name": "Cookshop", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/PgQtbdoMTIaWFstO1wvJLQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cookshop-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA", "review_count": 2120, "categories": [{"alias": "newamerican", "title": "American (New)"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}, {"alias": "wine_bars", "title": "Wine Bars"}], "rating": 4.0, "coordinates": {"latitude": 40.7454251, "longitude": -74.0056084}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "156 10th Ave", "address2": "", "address3": "", "city": "New York", "zip_code": "10011", "country": "US", "state": "NY", "display_address": ["156 10th Ave", "New York, NY 10011"]}, "phone": "+12129244440", "display_phone": "(212) 924-4440", "distance": 2799.3312228206055}, {"i ...

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "ETgJqJHV7BW6pIr9Ox74sA", "alias": "am\\u00e9lie-new-york", "name": "Am\\u00e9lie", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA", "review_count": 2702, "categories": [{"alias": "french", "title": "French"}, {"alias": "wine_bars", "title": "Wine Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.7327, "longitude": -73.99766}, "transactions": ["pickup", "restaurant_reservation", "delivery"], "price": "$$", "location": {"address1": "22 W 8th St", "address2": "", "address3": "", "city": "New York", "zip_code": "10011", "country": "US", "state": "NY", "display_address": ["22 W 8th St", "New York, NY 10011"]}, "phone": "+12125332962", "display_phone": "(212) 533-2962", "distance": 3464.4669936751793}, {"id": "6Ct7OeTRn4caY9g0swFBsw", "alias": "la-contenta-new-york", "name": "La Contenta", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/FwZAyPgdKdPGQ8aAGKh3-w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/la-contenta-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA", "review_count": 763, "categories": [{"alias": "mexican", "title": "Mexican"}, {"alias": "bars", "title": "Bars"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.5, "coordinates": {"latitude": 40.71873, "longitude": -73.98691}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "102 Norfolk St", "address2": "", "address3": "", "city": "New York", "zip_code": "10002", "country": "US", "state": "NY", "display_address": ["102 Norfolk St", "New York, NY 10002"]}, "phone": "+12124324180", "display_phone": "(212) 432-4180", "distance": 4662.3743595723645}, {"id": "ooYUO3Pq_qypc1NXFzeLYQ", "alias": "city-vineyard-new-york", "name": "City Vineyard", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/EQkP8Wd2bC_411mQMBtwXg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/city-vineyard-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA", "review_count": 940, "categories": [{"alias": "wine_bars", "title": "Wine Bars"}, {"alias": "newamerican", "title": "American (New)"}, {"alias": "venues", "title": "Venues & Event Spaces"}], "rating": 4.0, "coordinates": {"latitude": 40.7205582, "longitude": -74.0118093}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "233 West St", "address2": "", "address3": null, "city": "New York", "zip_code": "10013", "country": "US", "state": "NY", "display_address": ["233 West St", "New York, NY 10013"]}, "phone": "+16466778350", "display_phone": "(646) 677-8350", "distance": 5193.210804405722}, {"id": "ssGhu4n3emZ9kEPVf371IQ", "alias": "cookshop-new-york", "name": "Cookshop", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/PgQtbdoMTIaWFstO1wvJLQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cookshop-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA", "review_count": 2120, "categories": [{"alias": "newamerican", "title": "American (New)"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}, {"alias": "wine_bars", "title": "Wine Bars"}], "rating": 4.0, "coordinates": {"latitude": 40.7454251, "longitude": -74.0056084}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "156 10th Ave", "address2": "", "address3": "", "city": "New York", "zip_code": "10011", "country": "US", "state": "NY", "display_address": ["156 10th Ave", "New York, NY 10011"]}, "phone": "+12129244440", "display_phone": "(212) 924-4440", "distance": 2799.3312228206055}, {"i ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'alias': 'amélie-new-york',
#    'name': 'Amélie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 2702,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 8th St', 'New York, NY 10011']},
#    'phone': '+12125332962',
#    'display_phone': '(212) 533-2962',
#    'distance': 3464.4669936751793},
#   {'id': '6Ct7OeTRn4caY9g0swFBsw',
#    'alias': 'la-contenta-new-york',
#    'name': 'La Contenta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FwZAyPgdKdPGQ8aAGKh3-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-contenta-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 763,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71873, 'longitude': -73.98691},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Norfolk St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Norfolk St', 'New York, NY 10002']},
#    'phone': '+12124324180',
#    'display_phone': '(212) 432-4180',
#    'distance': 4662.3743595723645},
#   {'id': 'ooYUO3Pq_qypc1NXFzeLYQ',
#    'alias': 'city-vineyard-new-york',
#    'name': 'City Vineyard',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EQkP8Wd2bC_411mQMBtwXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-vineyard-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 940,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7205582, 'longitude': -74.0118093},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '233 West St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['233 West St', 'New York, NY 10013']},
#    'phone': '+16466778350',
#    'display_phone': '(646) 677-8350',
#    'distance': 5193.210804405722},
#   {'id': 'ssGhu4n3emZ9kEPVf371IQ',
#    'alias': 'cookshop-new-york',
#    'name': 'Cookshop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PgQtbdoMTIaWFstO1wvJLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cookshop-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 2120,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7454251, 'longitude': -74.0056084},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '156 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 10th Ave', 'New York, NY 10011']},
#    'phone': '+12129244440',
#    'display_phone': '(212) 924-4440',
#    'distance': 2799.3312228206055},
#   {'id': 'rp8S7scxOkVVeG7dNneMGQ',
#    'alias': 'l-artusi-new-york',
#    'name': "L'Artusi",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HeDloBW-SnokWblGDuPrUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1862,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73372, 'longitude': -74.00513},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '228 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 10th St', 'New York, NY 10014']},
#    'phone': '+12122555757',
#    'display_phone': '(212) 255-5757',
#    'distance': 3702.6967291210426},
#   {'id': 'N5UY113nNpeKdLPv0cbMjQ',
#    'alias': 'the-wild-son-new-york',
#    'name': 'The Wild Son',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bKbzwnDOl26D3aVzh-lj0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wild-son-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 504,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.727424, 'longitude': -73.985201},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '132 First Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 First Ave', 'New York, NY 10009']},
#    'phone': '+12127277900',
#    'display_phone': '(212) 727-7900',
#    'distance': 3690.7983417232585},
#   {'id': 'xTnivXEdEtXrnhp-z4JGvg',
#    'alias': 'la-parisienne-new-york-5',
#    'name': 'La Parisienne',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8i6Hgi2iOA06CgDK8ED4pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-parisienne-new-york-5?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 507,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.0093799},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16467564911',
#    'display_phone': '(646) 756-4911',
#    'distance': 6196.411979923868},
#   {'id': 'D2qV8sDdHEFlHbVz7VSHRQ',
#    'alias': 'black-tap-soho-new-york-3',
#    'name': 'Black Tap - Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3Jm6Riap3vSt7grwgISbvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-tap-soho-new-york-3?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1196,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.723794, 'longitude': -74.004193},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '529 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['529 Broome St', 'New York, NY 10013']},
#    'phone': '+19176393089',
#    'display_phone': '(917) 639-3089',
#    'distance': 4591.974972607585},
#   {'id': 'bW3mY-voyav37nU0uaLmNQ',
#    'alias': 'dante-new-york',
#    'name': 'Dante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KG1kurs7VTc48dQ-7tYGEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 366,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72879, 'longitude': -74.00165},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '79-81 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79-81 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129825275',
#    'display_phone': '(212) 982-5275',
#    'distance': 4000.901555055698},
#   {'id': 'nrwOQSXoRXfAYhkdjiUk8g',
#    'alias': 'toro-loco-new-york',
#    'name': 'Toro Loco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WXWUVnk5u1XaZV-fzAYV8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toro-loco-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 254,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70421, 'longitude': -74.01208},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Stone St', 'New York, NY 10004']},
#    'phone': '+19172620444',
#    'display_phone': '(917) 262-0444',
#    'distance': 6845.025266309657},
#   {'id': 'XsElXaLxUPKquI78poB8yw',
#    'alias': 'maison-pickle-new-york',
#    'name': 'Maison Pickle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AVfQDXs17sxfUWVz_z_0jQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-pickle-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1026,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7870473, 'longitude': -73.9781361},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2315 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2315 Broadway', 'New York, NY 10024']},
#    'phone': '+12124969100',
#    'display_phone': '(212) 496-9100',
#    'distance': 2983.7799112880234},
#   {'id': 'xQ445GaWVN5Aa3sFX9OoIg',
#    'alias': 'buvette-new-york',
#    'name': 'Buvette',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9iK14ZmXBwgWWW0wigP0pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buvette-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1765,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732704, 'longitude': -74.004317},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '42 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Grove St', 'New York, NY 10014']},
#    'phone': '+12122553590',
#    'display_phone': '(212) 255-3590',
#    'distance': 3753.3765765751923},
#   {'id': '0IwdwNnbro5RLLIlaxyfpQ',
#    'alias': 'the-wilson-new-york-2',
#    'name': 'The Wilson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4rn0I4qpKAIqPZAsMrhSew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wilson-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 167,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74587, 'longitude': -73.99265},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '132 W 27th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 27th St', 'New York, NY 10001']},
#    'phone': '+12125292671',
#    'display_phone': '(212) 529-2671',
#    'distance': 1987.2559059837151},
#   {'id': '8bIXIStb1SVu1sXYfcMH5g',
#    'alias': 'rubys-cafe-new-york-3',
#    'name': "Ruby's Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O_UqkNF91Uh0ywxnLjclXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubys-cafe-new-york-3?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 108,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730932, 'longitude': -73.988061},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '198 E 11th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['198 E 11th St', 'New York, NY 10003']},
#    'phone': '+16469984265',
#    'display_phone': '(646) 998-4265',
#    'distance': 3354.2406224100414},
#   {'id': 'Xd_l7jtUAZZAAvK8-mI2Jw',
#    'alias': 'the-smith-new-york-7',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iRt2bcEEBQgy6qQQwlPvtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-7?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1017,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74424, 'longitude': -73.98878},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1150 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1150 Broadway', 'New York, NY 10010']},
#    'phone': '+12126854500',
#    'display_phone': '(212) 685-4500',
#    'distance': 1977.2193388418018},
#   {'id': 'OAqsZMbjv66nOMqlimnYuQ',
#    'alias': 'uva-new-york',
#    'name': 'Uva',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OKw0xxKFXVRPNTRFx6v2Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uva-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 2419,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7722, 'longitude': -73.95566},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1486 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1486 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12124724552',
#    'display_phone': '(212) 472-4552',
#    'distance': 2341.9530202338674},
#   {'id': 'nI1UYDCYUTt23TpGxqnLKg',
#    'alias': 'buddakan-new-york',
#    'name': 'Buddakan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y0PGrSO6gicAmxH4BhU3EA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buddakan-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 4013,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7422762672197,
#     'longitude': -74.0048000961542},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12129896699',
#    'display_phone': '(212) 989-6699',
#    'distance': 2981.0496048609193},
#   {'id': 'zyyT2yiyxxamC-jKc0v-fg',
#    'alias': 'omars-kitchen-and-rum-bar-new-york',
#    'name': "Omar's Kitchen and Rum Bar",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3wyLFJ6QbIFnfoH91PTx5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omars-kitchen-and-rum-bar-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 81,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720422, 'longitude': -73.984525},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '29A Clinton St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29A Clinton St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4458.053369804921},
#   {'id': 'SWK0AQ5KTDDCt8AtOhhasg',
#    'alias': 'malibu-farm-new-york-2',
#    'name': 'Malibu Farm',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lbyxUaUcgBKAQzbir0nP_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malibu-farm-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 101,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.705925, 'longitude': -74.001749},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '89 S St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 S St', 'New York, NY 10038']},
#    'phone': '+12122653030',
#    'display_phone': '(212) 265-3030',
#    'distance': 6346.630001934347},
#   {'id': '2iW5TU4W0BN8LYBzVmO9Qw',
#    'alias': 'the-honey-well-new-york',
#    'name': 'The Honey Well',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uQQ7RHRMladMl5B1XgODag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-honey-well-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 218,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.82849, 'longitude': -73.94862},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3604 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3604 Broadway', 'New York, NY 10031']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 7994.972805055692},
#   {'id': 'vgg1dvDP-9tFWSacN4q0nA',
#    'alias': 'coppelia-new-york',
#    'name': 'Coppelia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sXzxZcMCd5ZH2RzZ26QJZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coppelia-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1352,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7389111700125,
#     'longitude': -73.9999985153443},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '207 W 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['207 W 14th St', 'New York, NY 10011']},
#    'phone': '+12128585001',
#    'display_phone': '(212) 858-5001',
#    'distance': 2981.793142335955},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'alias': 'the-cabin-nyc-new-york-2',
#    'name': 'The Cabin NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dc54M8OrhvbJLRkuSmdmHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cabin-nyc-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 251,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72393, 'longitude': -73.98383},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '205 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E 4th St', 'New York, NY 10009']},
#    'phone': '+12127770454',
#    'display_phone': '(212) 777-0454',
#    'distance': 4055.8669880946763},
#   {'id': 'DGhWO1sUWydVeR5j5ZZaMw',
#    'alias': 'la-grande-boucherie-new-york-2',
#    'name': 'La Grande Boucherie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lkc0FTvtITqYPKChk6A0Bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-grande-boucherie-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 59,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76268, 'longitude': -73.98093},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '145 W 53rd St',
#     'address2': 'New York',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 W 53rd St', 'New York', 'New York, NY 10019']},
#    'phone': '+12125107714',
#    'display_phone': '(212) 510-7714',
#    'distance': 332.9066883809004},
#   {'id': 'RzKR9QcYP03EQ_8DxTxowg',
#    'alias': 'barrio-chino-new-york',
#    'name': 'Barrio Chino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8PdXnElPeE7PVXLDuU6lKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrio-chino-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1109,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718022, 'longitude': -73.990026},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '253 Broome St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 Broome St', 'New York, NY 10002']},
#    'phone': '+12122286710',
#    'display_phone': '(212) 228-6710',
#    'distance': 4791.069494550982},
#   {'id': '5MpWHGQ6Qc-M4q1KL_nioA',
#    'alias': 'bar-b-new-york',
#    'name': 'Bar B',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rP6Gfe33cpkYe549tj_2BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-b-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 184,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7395804, 'longitude': -73.999118},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '84 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 7th Ave', 'New York, NY 10011']},
#    'phone': '+12122291888',
#    'display_phone': '(212) 229-1888',
#    'distance': 2887.7164858736137},
#   {'id': 'C-8mGN7lt5rIraO5n-15ug',
#    'alias': 'the-smith-new-york-2',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fGAZCdyPI8qil5boCzidBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 2676,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755165, 'longitude': -73.967868},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '956 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['956 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12126442700',
#    'display_phone': '(212) 644-2700',
#    'distance': 1057.0229649315834},
#   {'id': 'YSflX6shqcP3zYno0Zz75Q',
#    'alias': 'while-we-were-young-new-york',
#    'name': 'While We Were Young',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/I5QdRi1JuxzSIqgYJML8dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/while-we-were-young-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 355,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73437, 'longitude': -74.00272},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '183 W 10th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['183 W 10th St', 'New York, NY 10014']},
#    'phone': '+19176756272',
#    'display_phone': '(917) 675-6272',
#    'distance': 3530.176523895788},
#   {'id': 'cTE0e96GYzet799EJeStoQ',
#    'alias': 'chama-mama-new-york',
#    'name': 'Chama Mama',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7F5i7rUgxBJip23brHPBiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chama-mama-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 339,
#    'categories': [{'alias': 'georgian', 'title': 'Georgian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7384, 'longitude': -73.99892},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '149 W 14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 W 14th St', 'New York, NY 10011']},
#    'phone': '+16464389007',
#    'display_phone': '(646) 438-9007',
#    'distance': 2966.180331463606},
#   {'id': 'XipQLDbyTl5tsLlyzAWzug',
#    'alias': 'jajaja-plantas-mexicana-new-york-2',
#    'name': 'Jajaja Plantas Mexicana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OkWKXxOZBLJO7hRjOlIMig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-plantas-mexicana-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 961,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7141530317142,
#     'longitude': -73.9904247969389},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '162 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E Broadway', 'New York, NY 10002']},
#    'phone': '+16468835453',
#    'display_phone': '(646) 883-5453',
#    'distance': 5219.447623946914},
#   {'id': 'Rj2ACaJcbroJLPDhRhzvBw',
#    'alias': 'shuka-new-york-3',
#    'name': 'Shuka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s46eH_qJRLtAXaJguMg-VQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shuka-new-york-3?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 499,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72707, 'longitude': -74.00283},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '38 MacDougal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 MacDougal St', 'New York, NY 10012']},
#    'phone': '+12124757500',
#    'display_phone': '(212) 475-7500',
#    'distance': 4217.946685020116},
#   {'id': 'mWS4umRg2AyykyAClMrIRw',
#    'alias': 'the-penrose-new-york',
#    'name': 'The Penrose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YDYUed0l4okORNytlggAyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-penrose-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1203,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.775427, 'longitude': -73.953115},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1590 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1590 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12122032751',
#    'display_phone': '(212) 203-2751',
#    'distance': 2723.883238157801},
#   {'id': 'AA9wpuJRhkSHUePAiv3otA',
#    'alias': 'the-leroy-house-new-york-5',
#    'name': 'The Leroy House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2gFtU7B5tZx4WVtl5jiwjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-leroy-house-new-york-5?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 91,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73063, 'longitude': -74.00661},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '430 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['430 Hudson St', 'New York, NY 10014']},
#    'phone': '+16465900640',
#    'display_phone': '(646) 590-0640',
#    'distance': 4050.285940443716},
#   {'id': 'twHJyFgUSd7wzioKQjE7Jw',
#    'alias': 'galli-new-york-5',
#    'name': 'Galli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NriJMGzJm4mZn-Pj2oRm3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galli-new-york-5?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 950,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72161, 'longitude': -74.00127},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45 Mercer St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Mercer St', 'New York, NY 10013']},
#    'phone': '+12129669288',
#    'display_phone': '(212) 966-9288',
#    'distance': 4699.174505441503},
#   {'id': '9GBqbQ415CXaBa2gwHyFHQ',
#    'alias': 'sveta-new-york',
#    'name': 'Sveta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1q_4Ssjl1SvHju5VHK3o8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sveta-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 80,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72967, 'longitude': -74.00421},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '64 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Carmine St', 'New York, NY 10014']},
#    'phone': '+12122034106',
#    'display_phone': '(212) 203-4106',
#    'distance': 4021.345303287223},
#   {'id': 'XO3yD87rTPz9o6Dy9qRaJg',
#    'alias': 'the-spaniard-new-york',
#    'name': 'The Spaniard',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KPavp-rEuY3WQK5CSBK7kQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-spaniard-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 259,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7327497, 'longitude': -74.0021829},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '190 W 4th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 W 4th St', 'New York, NY 10014']},
#    'phone': '+12129181986',
#    'display_phone': '(212) 918-1986',
#    'distance': 3647.890233212861},
#   {'id': 'JYNBy2r3LVhJbLHE1bASfg',
#    'alias': 'the-smith-new-york-3',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wcwUFAyZ1X-thnem2s6WPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-3?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1740,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7716201269986,
#     'longitude': -73.9818377981476},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1900 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1900 Broadway', 'New York, NY 10023']},
#    'phone': '+12124965700',
#    'display_phone': '(212) 496-5700',
#    'distance': 1298.9737992359637},
#   {'id': 'fuS39acPaRi38DhSSwEI4Q',
#    'alias': 'felice-new-york-6',
#    'name': 'Felice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RjmwyXZWgYk0IPqigCTjzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/felice-new-york-6?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 370,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70789, 'longitude': -74.00712},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Gold St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Gold St', 'New York, NY 10038']},
#    'phone': '+12127855950',
#    'display_phone': '(212) 785-5950',
#    'distance': 6299.336651839251},
#   {'id': 'RPP_wHhM8yZYIP5W-YHk6Q',
#    'alias': 'fumo-new-york-3',
#    'name': 'Fumo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nqabsyMKaqjqCFul1yerEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fumo-new-york-3?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 79,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80284, 'longitude': -73.968119},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2791 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2791 Broadway', 'New York, NY 10025']},
#    'phone': '+16468222921',
#    'display_phone': '(646) 822-2921',
#    'distance': 4819.612835669943},
#   {'id': 'aSFBv64GBpMOFPqIleeQFQ',
#    'alias': 'lure-fishbar-new-york-2',
#    'name': 'Lure Fishbar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uUa1NJdRR4iljdfu6D1V8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lure-fishbar-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1665,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724612166991, 'longitude': -73.998574708004},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '142 Mercer St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Mercer St', 'New York, NY 10012']},
#    'phone': '+12124317676',
#    'display_phone': '(212) 431-7676',
#    'distance': 4304.947803544696},
#   {'id': 'UJe9_p6NEl0kA6xHVo5PKw',
#    'alias': 'amelie-new-york-2',
#    'name': 'Amelie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Dn-MbEQvRT8HzHp_qTf-MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amelie-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 209,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78875, 'longitude': -73.97464},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '566 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['566 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16464227167',
#    'display_phone': '(646) 422-7167',
#    'distance': 3191.820589668884},
#   {'id': 'riykDqJw_NPGssLgqCeD-Q',
#    'alias': 'aunt-jakes-new-york-4',
#    'name': "Aunt Jake's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9Wvs6ueo5Sn-aVEmRwJ05g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunt-jakes-new-york-4?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 38,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.774587, 'longitude': -73.954513},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1555 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1555 2nd Ave', 'New York, NY 10028']},
#    'phone': '+19172615040',
#    'display_phone': '(917) 261-5040',
#    'distance': 2577.0827972409556},
#   {'id': 'tHW3EwGwai1AiWQ6ZD-wjg',
#    'alias': 'industry-kitchen-new-york',
#    'name': 'Industry Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AD5JNSSWmEas2aw0S8iN4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/industry-kitchen-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 640,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7049434740873,
#     'longitude': -74.0048825740814},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '70 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 South St', 'New York, NY 10005']},
#    'phone': '+12124879600',
#    'display_phone': '(212) 487-9600',
#    'distance': 6535.559646229837},
#   {'id': '26E3j9l0XW_onVIUP-ThCw',
#    'alias': 'heidis-house-by-the-side-of-the-road-new-york-2',
#    'name': "Heidi's House By The Side Of The Road",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/29Z6Thcc591JVESABqZafQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heidis-house-by-the-side-of-the-road-new-york-2?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 623,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.772189, 'longitude': -73.955029},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '308 E 78th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 E 78th St', 'New York, NY 10075']},
#    'phone': '+12122490069',
#    'display_phone': '(212) 249-0069',
#    'distance': 2383.28550485997},
#   {'id': 'hmG5OnHEe2vQRrQxez0U9w',
#    'alias': 'worthwild-new-york',
#    'name': 'Worthwild',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KVUdxRPC1BJsImaGRb7bng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/worthwild-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 72,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74428, 'longitude': -74.00272},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '156 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 9th Ave', 'New York, NY 10011']},
#    'phone': '+17189429385',
#    'display_phone': '(718) 942-9385',
#    'distance': 2697.584062175352},
#   {'id': 'nm5rcWNmfevNXLNQAITi5w',
#    'alias': 'clinton-hall-new-york',
#    'name': 'Clinton Hall',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2lzQDOPoz62wZ5e3WiXmig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-hall-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 665,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70803, 'longitude': -74.014869},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '90 Washington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Washington St', 'New York, NY 10006']},
#    'phone': '+12123636000',
#    'display_phone': '(212) 363-6000',
#    'distance': 6562.112194919561},
#   {'id': 'oqeeOpA2S6U02nUGa8Ot7g',
#    'alias': 'alison-new-york',
#    'name': 'Alison',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7bkdpEZThLboAgwf8M2qDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alison-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 56,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7909561630924,
#     'longitude': -73.9469904452562},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1651 Lexington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1651 Lexington Ave', 'New York, NY 10029']},
#    'phone': '+16468761054',
#    'display_phone': '(646) 876-1054',
#    'distance': 4327.180760520508},
#   {'id': 'k5NAz3-goMXKoUqPfOZ1Hw',
#    'alias': 'the-smith-new-york',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-QnXtc_AwQl5MJOHoEpUJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1972,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.730957886229, 'longitude': -73.9886217},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '55 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12124209800',
#    'display_phone': '(212) 420-9800',
#    'distance': 3363.1104696266534},
#   {'id': 's3jou_L_LVYGkNHiuhjlew',
#    'alias': 'boucherie-west-village-new-york-3',
#    'name': 'Boucherie West Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gGTUB2AHF7sK5u-wdjO8DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 1537,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '99 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128371616',
#    'display_phone': '(212) 837-1616',
#    'distance': 3651.3436314400974},
#   {'id': '0FaLilJs2VN83hOEBcBnPg',
#    'alias': 'au-zaatar-new-york',
#    'name': "Au Za'atar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qwjkj1qkdcOKKOIGwbYutg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/au-zaatar-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 965,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728901, 'longitude': -73.981185},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '188 Avenue A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Avenue A', 'New York, NY 10009']},
#    'phone': '+12122545660',
#    'display_phone': '(212) 254-5660',
#    'distance': 3489.281528088423},
#   {'id': '6gDUVNZo0E9lxO2DkAhHOQ',
#    'alias': 'the-greek-new-york',
#    'name': 'The Greek',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aruZfq7Ey67IHXTXmF9MAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greek-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#    'review_count': 484,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7237145, 'longitude': -74.0096166},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '458 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['458 Greenwich St', 'New York, NY 10013']},
#    'phone': '+16464763941',
#    'display_phone': '(646) 476-3941',
#    'distance': 4831.641617134865}],
#  'total': 3000,
#  'region': {'center': {'longitude': -73.97850036621094,
#    'latitude': 40.76021491079617}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'x25t8G_7Lo9Wd7Grdn_HEw',
#    'alias': 'blink-fitness-125th-new-york-2',
#    'name': 'Blink Fitness - 125th',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dPDZSOyPuHm-a9Xr_6nUKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-125th-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 106,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.81054, 'longitude': -73.951461},
#    'transactions': [],
#    'location': {'address1': '301 W 125th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['301 W 125th St', 'New York, NY 10027']},
#    'phone': '+16462539700',
#    'display_phone': '(646) 253-9700',
#    'distance': 655.4204041035346},
#   {'id': 'JvFSaSbopX2T4mgiGl0I0A',
#    'alias': 'new-york-sports-clubs-new-york-72',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZKK4la6H97CVB4zvlGDIog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-72?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 143,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.8231394215693,
#     'longitude': -73.9420633844566},
#    'transactions': [],
#    'location': {'address1': '303 W 145th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10039',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['303 W 145th St', 'New York, NY 10039']},
#    'phone': '+12122340016',
#    'display_phone': '(212) 234-0016',
#    'distance': 995.6980342856355},
#   {'id': 'Oych8H3fLi8HCzsaQRvb_Q',
#    'alias': 'benswic-inc-new-york-2',
#    'name': 'Benswic, Inc',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ngRjyTIXxAwiEDsZ9k8jOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benswic-inc-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 7,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'summer_camps', 'title': 'Summer Camps'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.8149829, 'longitude': -73.947843},
#    'transactions': [],
#    'location': {'address1': '2473 Frederick Douglass',
#     'address2': 'Blvd Fl 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2473 Frederick Douglass',
#      'Blvd Fl 1',
#      'New York, NY 10027']},
#    'phone': '+19176593549',
#    'display_phone': '(917) 659-3549',
#    'distance': 207.92086966819383},
#   {'id': 'v1oSEKjF7EQGLQHR-zVPtw',
#    'alias': 'blink-fitness-harlem-116th-new-york',
#    'name': 'Blink Fitness - Harlem 116th',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q1m6xa3c46BIUOnAmSO3DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-harlem-116th-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 79,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.801442, 'longitude': -73.947629},
#    'transactions': [],
#    'location': {'address1': '27 W 116th Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 W 116th Street', 'New York, NY 10026']},
#    'phone': '+16465615454',
#    'display_phone': '(646) 561-5454',
#    'distance': 1658.1750202228752},
#   {'id': 'Z4ygiHjI9PSjEH4JlpIixw',
#    'alias': 'jtw-fit-new-york-2',
#    'name': 'JTW Fit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bnQ1bNVGeuxewpfD2KXyvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jtw-fit-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 14,
#    'categories': [{'alias': 'boxing', 'title': 'Boxing'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.813054, 'longitude': -73.944908},
#    'transactions': [],
#    'location': {'address1': '2235 Adam Clayton Powell Jr Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2235 Adam Clayton Powell Jr Blvd',
#      'New York, NY 10027']},
#    'phone': '+12039368326',
#    'display_phone': '(203) 936-8326',
#    'distance': 536.9085119591264},
#   {'id': 'cP7aVia5GvvSkj9cGNZB8w',
#    'alias': 'new-york-sports-clubs-new-york-67',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N945KOx6k45n_uMM0Rpa4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-67?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 104,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.8097714446788,
#     'longitude': -73.9517667889596},
#    'transactions': [],
#    'location': {'address1': '2311 Frederick Douglas Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2311 Frederick Douglas Blvd', 'New York, NY 10027']},
#    'phone': '+12123162500',
#    'display_phone': '(212) 316-2500',
#    'distance': 744.5325380004037},
#   {'id': 'B9hepOn0_ZN2YMuShBP-Tw',
#    'alias': 'liberated-fitness-new-york',
#    'name': 'Liberated Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u8irLYSuIsSUcgJ_ljPdMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberated-fitness-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 18,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8013887, 'longitude': -73.9611277},
#    'transactions': [],
#    'location': {'address1': '1005 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1005 Columbus Ave', 'New York, NY 10025']},
#    'phone': '+18578916133',
#    'display_phone': '(857) 891-6133',
#    'distance': 1914.5426419497421},
#   {'id': 'ku3CmsmQ2a81XcAVc8I1Fw',
#    'alias': 'planet-fitness-new-york-40',
#    'name': 'Planet Fitness',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9fWM1YTKxMBDmzZdJt97Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-fitness-new-york-40?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 109,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.808869, 'longitude': -73.949206},
#    'transactions': [],
#    'location': {'address1': '208 W 125th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 W 125th St', 'New York, NY 10027']},
#    'phone': '+12124972644',
#    'display_phone': '(212) 497-2644',
#    'distance': 824.3770713021464},
#   {'id': 'oAwyvQiSWGoGY9ksh4yQRw',
#    'alias': 'befitnyc-new-york',
#    'name': 'befitnyc',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rc0X-tsaoVewn_2j_YzPrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/befitnyc-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 23,
#    'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'cardioclasses', 'title': 'Cardio Classes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.799915, 'longitude': -73.967651},
#    'transactions': [],
#    'location': {'address1': '2726 Broadway',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2726 Broadway', 'Fl 2', 'New York, NY 10025']},
#    'phone': '+16466660978',
#    'display_phone': '(646) 666-0978',
#    'distance': 2365.7691857867985},
#   {'id': '6xuEvehxXWFvd7EGW9p5lg',
#    'alias': 'harlem-branch-ymca-new-york',
#    'name': 'Harlem Branch YMCA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CiZ8YiI899j1bMJ2Viqhsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlem-branch-ymca-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 34,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'childcare', 'title': 'Child Care & Day Care'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.81479, 'longitude': -73.94291},
#    'transactions': [],
#    'location': {'address1': '180 W 135th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10030',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 W 135th St', 'New York, NY 10030']},
#    'phone': '+12129122100',
#    'display_phone': '(212) 912-2100',
#    'distance': 592.6934314426277},
#   {'id': 'qI2_gqEih2Zz2r9uCpqv5A',
#    'alias': 'columbia-university-dodge-fitness-center-new-york',
#    'name': 'Columbia University Dodge Fitness Center',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xepiMTHmSVzeZcpyT6ZhVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/columbia-university-dodge-fitness-center-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 46,
#    'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'swimmingpools', 'title': 'Swimming Pools'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.810399, 'longitude': -73.962067},
#    'transactions': [],
#    'location': {'address1': 'Columbia University',
#     'address2': '',
#     'address3': '3030 Broadway',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Columbia University',
#      '3030 Broadway',
#      'New York, NY 10027']},
#    'phone': '+12128542546',
#    'display_phone': '(212) 854-2546',
#    'distance': 1231.615303016337},
#   {'id': 'CnY_KPqSuKIFCZHsQDRG6g',
#    'alias': 'ilovekickboxing-harlem-new-york',
#    'name': 'iLoveKickboxing- Harlem',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5u4TY-kARGmyn8l7p60TGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ilovekickboxing-harlem-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 86,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'kickboxing', 'title': 'Kickboxing'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8017641681891,
#     'longitude': -73.9484703540802},
#    'transactions': [],
#    'location': {'address1': '47 West 116th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 West 116th St', 'New York, NY 10026']},
#    'phone': '+13473446220',
#    'display_phone': '(347) 344-6220',
#    'distance': 1616.6167127871245},
#   {'id': '-Dx2re0yYz0CZCOF8qkwIg',
#    'alias': 'hansborough-recreation-center-nyc-parks-dept-new-york',
#    'name': 'Hansborough Recreation Center - NYC Parks Dept.',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ppx0QAVSXkN6_6pkqsl5ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hansborough-recreation-center-nyc-parks-dept-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 14,
#    'categories': [{'alias': 'swimmingpools', 'title': 'Swimming Pools'},
#     {'alias': 'recreation', 'title': 'Recreation Centers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8128280639648,
#     'longitude': -73.9393157958984},
#    'transactions': [],
#    'location': {'address1': '35 W 134th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10037',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 134th St', 'New York, NY 10037']},
#    'phone': '+12122349603',
#    'display_phone': '(212) 234-9603',
#    'distance': 959.6072397481556},
#   {'id': '7QN3-rRh86x5vKzN2H7Bzw',
#    'alias': 'anytime-fitness-cliffside-park',
#    'name': 'Anytime Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q0O96q01DhYOb0UMPAT30g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-fitness-cliffside-park?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 11,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.828273, 'longitude': -73.987101},
#    'transactions': [],
#    'location': {'address1': '1 Towne Center Dr',
#     'address2': 'Ste 1008/1009',
#     'address3': None,
#     'city': 'Cliffside Park',
#     'zip_code': '07010',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Towne Center Dr',
#      'Ste 1008/1009',
#      'Cliffside Park, NJ 07010']},
#    'phone': '+12019177277',
#    'display_phone': '(201) 917-7277',
#    'distance': 3421.2416289879325},
#   {'id': 'APzU2CBC7Gzwa2RTnUdAAQ',
#    'alias': 'bodystrength-fitness-new-york-2',
#    'name': 'BodyStrength Fitness',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hKLDiaqJbrZIu1CNasKnkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodystrength-fitness-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 104,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.800996, 'longitude': -73.9674816},
#    'transactions': [],
#    'location': {'address1': '250 W 106th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 W 106th St', 'Fl 2', 'New York, NY 10025']},
#    'phone': '+12123163338',
#    'display_phone': '(212) 316-3338',
#    'distance': 2266.2255951703714},
#   {'id': '0xjtdAiLrNDQy08VNtJUdg',
#    'alias': 'planet-fitness-new-york-37',
#    'name': 'Planet Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9X_H7HJGL0CiuwbYpqWmTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-fitness-new-york-37?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 74,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.83455, 'longitude': -73.94504},
#    'transactions': [],
#    'location': {'address1': '3799 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3799 Broadway', 'New York, NY 10032']},
#    'phone': '+12123360830',
#    'display_phone': '(212) 336-0830',
#    'distance': 2068.974971700407},
#   {'id': 'XsCcKxJQThO__zfMCZHPig',
#    'alias': 'blink-fitness-bronx-18',
#    'name': 'Blink Fitness',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3Ouj2lYcBHq1hms_fMWlmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-bronx-18?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 7,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.816857399717, 'longitude': -73.917223849458},
#    'transactions': [],
#    'location': {'address1': '570 Melrose Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10455',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['570 Melrose Ave', 'Bronx, NY 10455']},
#    'phone': '+13473386459',
#    'display_phone': '(347) 338-6459',
#    'distance': 2730.4705003243166},
#   {'id': 'Z42S9ucaD5xIvdGB_vkCTA',
#    'alias': 'the-monterey-health-club-new-york',
#    'name': 'The Monterey Health Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8BX-USsXM3xdJ66NyByoIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monterey-health-club-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 4,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78557, 'longitude': -73.94975},
#    'transactions': [],
#    'location': {'address1': '175 E 96th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['175 E 96th St', 'New York, NY 10128']},
#    'phone': '+12129968200',
#    'display_phone': '(212) 996-8200',
#    'distance': 3402.7444065892914},
#   {'id': 'G3Pi--DpJcsV5xS4HWp8Qw',
#    'alias': 'new-york-sports-clubs-new-york-82',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xAaxpvfGKiCBgQYExTYKSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-82?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 58,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.800343, 'longitude': -73.946862},
#    'transactions': [],
#    'location': {'address1': '1400 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1400 5th Ave', 'New York, NY 10026']},
#    'phone': '+12127221185',
#    'display_phone': '(212) 722-1185',
#    'distance': 1787.1302832593587},
#   {'id': 'jjsE8j5JYzDJjlLitVHO_g',
#    'alias': 'orangetheory-fitness-edgewater-edgewater',
#    'name': 'Orangetheory Fitness Edgewater',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/so1A_JmV9epejRqSM-OXzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orangetheory-fitness-edgewater-edgewater?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 137,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8188095, 'longitude': -73.9774704},
#    'transactions': [],
#    'location': {'address1': '725 River Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Edgewater',
#     'zip_code': '07020',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['725 River Rd', 'Edgewater, NJ 07020']},
#    'phone': '+12012126388',
#    'display_phone': '(201) 212-6388',
#    'distance': 2363.6809342884226}],
#  'total': 314,
#  'region': {'center': {'longitude': -73.94966125488281,
#    'latitude': 40.81627479820395}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = response.json()

# %%
What are the keys in this dictionary and the datatypes of their values.
# Out:
#   File "<ipython-input-32-2cba7e6cfbf7>", line 1
#     What are the keys in this dictionary and the datatypes of their values.
#            ^
# SyntaxError: invalid syntax

# %%
# your code here 

for key in data.keys(): 
    print(key)
    print(type(data[key]))
# Out:
# businesses
# <class 'list'>
# total
# <class 'int'>
# region
# <class 'dict'>

# %% [markdown]
# How many results did our query return?

# %%
data['total']
# Out:
# 3000

# %% [markdown]
# How many businesses were returned from the API call?

# %%
len(data['businesses'])
# Out:
# 50

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][0]

# %%
business
# Out:
# {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#  'alias': 'amélie-new-york',
#  'name': 'Amélie',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=HX7Zg3hgCbFKs_FeotRdCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=HX7Zg3hgCbFKs_FeotRdCA',
#  'review_count': 2702,
#  'categories': [{'alias': 'french', 'title': 'French'},
#   {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#  'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '22 W 8th St',
#   'address2': '',
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10011',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['22 W 8th St', 'New York, NY 10011']},
#  'phone': '+12125332962',
#  'display_phone': '(212) 533-2962',
#  'distance': 3464.4669936751793}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_tuple = (business['name'], 
            business['location']['display_address'][0] , 
            business['rating'])

# %%
biz_tuple
# Out:
# ('Amélie', '22 W 8th St', 4.5)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    parsed_data = []
    
    # loop through our business and parse each individual business
    for business in list_of_data:
        #print(business['name'])
        biz_tuple = (business['name'], 
            business['location']['display_address'][0] , 
            business['rating'])
    # in the loop, add each individual parsed  business to our data container
        parsed_data.append(biz_tuple)

    # return the container with all of the parsed results
    return parsed_data

# %%
parsed_results = parse_data(data['businesses'])

# %%
cursor.execute_many(query_statement, parsed_results)
